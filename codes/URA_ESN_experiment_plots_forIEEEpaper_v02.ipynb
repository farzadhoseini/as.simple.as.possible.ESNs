# %% [markdown]
# # URA ESN vs LSTM experiment driver (v02)
#
# 1. Run ESN HPO per basin.
# 2. Retrain ESNs with 10 seeds per basin.
# 3. Compare LSTM vs ESN across URA.

# %%
# %run plot_figs_02_03.py --base_dir "F:\Experiments\ESNs\main_jdelser_fh_v09\data\ESN_LSTM_comparison"

# %%
# %run plot_figs_04.py

# %%
# %run plot_figs_05.py
# Out:
# ===== Basin: Lasarte =====
# c:\Users\hosseinifh\AppData\Local\anaconda3\envs\MyPy_env2025\lib\site-packages\numpy\lib\nanfunctions.py:1563: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# c:\Users\hosseinifh\AppData\Local\anaconda3\envs\MyPy_env2025\lib\site-packages\numpy\lib\nanfunctions.py:1563: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# Saved metrics to: F:\Experiments\ESNs\main_jdelser_fh_v09\results\hydrographs\URA_metrics_events_only_3models.csv
# Saved event exam summary to: F:\Experiments\ESNs\main_jdelser_fh_v09\results\hydrographs\URA_event_exam_summary_NSE_thresholds.csv
