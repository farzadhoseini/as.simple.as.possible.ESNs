# %% [markdown]
# # URA ESN vs LSTM experiment driver (v02)
#
# 1. Run ESN HPO per basin.
# 2. Retrain ESNs with 10 seeds per basin.
# 3. Compare LSTM vs ESN across URA.

# %%
from pathlib import Path
from esn_local_URA_v01 import ROOT_DIR
ROOT_DIR
# Out:
# WindowsPath('F:/Experiments/ESNs/main_jdelser_fh_v08')

# %%
import esn_local_URA_HPO_v01 as hpo_ura
hpo_ura.main()
# Out:
# 2025-12-11 13:16:59,415 - INFO - Starting URA ESN HPO for 8 basins.
# 2025-12-11 13:16:59,419 - INFO - ----- Basin 1/8: Aixola -----
# 2025-12-11 13:16:59,419 - INFO - === HPO for basin 'Aixola' ===
# 2025-12-11 13:17:14,267 - INFO - Using per-basin windows from basins_info for basin 'Aixola': n_train=87648, n_valid=43824, n_test=35064
# 2025-12-11 13:19:43,217 - INFO - [Aixola] Trial 5/500, score=0.4988 (best=0.5627 so far)
# 2025-12-11 13:24:03,975 - INFO - [Aixola] Trial 10/500, score=-26.0704 (best=0.5913 so far)
# 2025-12-11 13:28:39,035 - INFO - [Aixola] Trial 15/500, score=0.6380 (best=0.6380 so far)
# 2025-12-11 13:33:03,246 - INFO - [Aixola] Trial 20/500, score=0.4927 (best=0.6380 so far)
# 2025-12-11 13:36:45,234 - INFO - [Aixola] Trial 25/500, score=0.6049 (best=0.6380 so far)
# 2025-12-11 13:40:36,050 - INFO - [Aixola] Trial 30/500, score=0.5666 (best=0.6380 so far)
# 2025-12-11 13:46:35,456 - INFO - [Aixola] Trial 35/500, score=0.1723 (best=0.6380 so far)
# ...

# %%
import ESN_seeds_URA_v01 as seeds_ura
seeds_ura.main()

# %%
import ComparingLSTMsvsESNs_URA_v01 as cmp_ura
cmp_ura.main()
# Out:
# ===== Basin 1/40: Abetxuko =====
# ===== Basin 2/40: Abusu =====
# ===== Basin 3/40: Agauntza =====
# ===== Basin 4/40: Aitzu =====
# ===== Basin 5/40: Aixola =====
# ===== Basin 6/40: Aizarnazabal =====
# ===== Basin 7/40: Alegia =====
# ===== Basin 8/40: Alegria =====
# ===== Basin 9/40: Altzola =====
# ===== Basin 10/40: Amorebieta =====
# ===== Basin 11/40: Anarbe =====
# ===== Basin 12/40: Araxes =====
# ===== Basin 13/40: Arenao =====
# ===== Basin 14/40: Areta =====
# ===== Basin 15/40: Balmaseda =====
# ===== Basin 16/40: Eibar =====
# ===== Basin 17/40: Elorrio =====
# ===== Basin 18/40: Erenozu =====
# ===== Basin 19/40: Estanda =====
# ===== Basin 20/40: Etura =====
# ===== Basin 21/40: Gardea =====
# ===== Basin 22/40: Gatika =====
# ===== Basin 23/40: Herrerias =====
# ===== Basin 24/40: Ibaieder =====
# ===== Basin 25/40: Jaizubia =====
# ===== Basin 26/40: Larrainazubi =====
# ===== Basin 27/40: Lasarte =====
# ===== Basin 28/40: Leitzaran =====
# ...

# %%
import importlib
import ComparingLSTMsvsESNs_URA_v06 as cmp_ura6

importlib.reload(cmp_ura6)
cmp_ura6.main()
# Out:
# Basins: ['Abetxuko', 'Abusu', 'Agauntza', 'Aitzu', 'Aixola', 'Aizarnazabal', 'Alegia', 'Alegria', 'Altzola', 'Amorebieta', 'Anarbe', 'Araxes', 'Arenao', 'Areta', 'Balmaseda', 'Eibar', 'Elorrio', 'Erenozu', 'Estanda', 'Etura', 'Gardea', 'Gatika', 'Herrerias', 'Ibaieder', 'Jaizubia', 'Larrainazubi', 'Lasarte', 'Leitzaran', 'Markina', 'Muxika', 'Oiartzun', 'Onati', 'Otxandio', 'Ozaeta', 'Sangroniz', 'SanPrudentzio', 'Saratxo', 'Sodupe', 'Urkizu', 'Zaratamo']
# Area column used: area_km2
# ===== Basin: Abetxuko =====
#   Q98 threshold for SFobs = 0.2261
#   Detected 11 high-flow events.
# ===== Basin: Abusu =====
#   Q98 threshold for SFobs = 0.6155
#   Detected 41 high-flow events.
# f:\Experiments\ESNs\main_jdelser_fh_v08\codes\metrics_rev.py:324: RuntimeWarning: invalid value encountered in log
#   obs = np.log(obs)
# f:\Experiments\ESNs\main_jdelser_fh_v08\codes\metrics_rev.py:324: RuntimeWarning: invalid value encountered in log
#   obs = np.log(obs)
# ...
